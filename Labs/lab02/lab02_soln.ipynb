# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # Lab 2: Pandas Overview
#
# **This lab is due Thursday, 9/15/2020 at 11:59PM.**

# %% [markdown]
# [Pandas](https://pandas.pydata.org/) is one of the most widely used Python libraries in data science. In this lab, you will learn commonly used data wrangling operations and tools in Pandas. We aim to give you familiarity with:
#
# * Creating dataframes
# * Slicing data frames (i.e., selecting rows and columns)
# * Filtering data (using boolean arrays)
# * Data Aggregation and Grouping in dataframes
#
# In this lab, you are going to use several pandas methods like `drop()`, `loc()`, `groupby()`. Remember that you can press `shift+tab` on any method to see the documentation for that method.

# %% [markdown]
# ## Setup

# %%
# Import the following packages. Note the shorthand for pandas.
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %% [markdown]
# ## Part 1: Creating DataFrames & Basic Manipulations
#
# A [dataframe](https://pandas.pydata.org/pandas-docs/stable/user_guide/dsintro.html#dataframe) is a two-dimensional labeled data structure with columns holding data of potentially different types.

# %% [markdown]
# **Method 1: ** You can create a data frame by specifying the columns and values as shown below.
#
# Notice the syntax: you're passing a dictionary into the DataFrame.  The keys become the column names (e.g. `'name'`), and the values are lists (`['Peter',....`)

# %%
animals = pd.DataFrame(
    data={'name': ['Peter', 'Nutkin', 'Hunca Munca', 'Jemima'],
          'species': ['rabbit', 'squirrel', 'mouse', 'duck']
          })
animals
# Out:
#           name   species
# 0        Peter    rabbit
# 1       Nutkin  squirrel
# 2  Hunca Munca     mouse
# 3       Jemima      duck

# %% [markdown]
# **Method 2: ** You can also define a dataframe by specifying the rows like below.
#
# Here, you're passing in tuples for each row of data (e.g. `("Peter", "rabbit")`) and specifying the column names separately.

# %%
animals2 = pd.DataFrame(
    [("Peter", "rabbit"), ("Nutkin", "squirrel"), ("Hunca Munca", "mouse"),
     ("Jemima", "duck")], 
    columns = ["name", "species"])
animals2
# Out:
#           name   species
# 0        Peter    rabbit
# 1       Nutkin  squirrel
# 2  Hunca Munca     mouse
# 3       Jemima      duck

# %% [markdown]
# **Other methods**: Usually you won't be creating data frames in such a manual way.  You'll often be loading dataframes in from other file types -- for example, comma separated (csv) files.  More on that later.

# %% [markdown]
# You can obtain the dimensions of a dataframe by using the shape attribute, `dataframe.shape`

# %%
(num_rows, num_columns) = animals.shape
num_rows, num_columns
# Out:
# (4, 2)

# %% [markdown]
# ### Question 1
#
# You can add a column using the syntax `dataframe['new column name'] = [data]`. Add a column called `favorite food` to the `animals` table which contains the strings 'nut', 'carrot', 'corn', and 'cheese'. Use your best guess as to which animal prefers which food.
#
# (note you'll need to comment out or delete the `NotImplementedError()`)

# %%
# YOUR CODE HERE
animals['favorite food'] = ['carrot','nut','cheese','corn']
# raise NotImplementedError()

# %%
animals
# Out:
#           name   species favorite food
# 0        Peter    rabbit        carrot
# 1       Nutkin  squirrel           nut
# 2  Hunca Munca     mouse        cheese
# 3       Jemima      duck          corn

# %% [markdown]
# ### Question 2
#
# Use the `.drop()` method to [drop](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.drop.html) the `favorite food` column you created, and save the new dataframe (without the `favorite food` column) to `animals_original`. Some notes:
#
# * You'll need to look up `drop` to figure out the right syntax.
# * Make sure to use the `axis` parameter correctly

# %%
# YOUR CODE HERE
animals_original = animals.drop(['favorite food'], axis=1)
#raise NotImplementedError()

# %%
animals_original
# Out:
#           name   species
# 0        Peter    rabbit
# 1       Nutkin  squirrel
# 2  Hunca Munca     mouse
# 3       Jemima      duck

# %%
assert animals_original.shape[1] == 2

# %% [markdown]
# ### Question 3
#
# Use the `.rename()` method to [rename](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.rename.html) the columns of `animals_original` so they begin with a capital letter. Set the `inplace` parameter correctly to change the `animals_original` dataframe. (hint: in Question 2, `drop` creates and returns a new dataframe instead of changing `animals` because `inplace` by default is `False`)

# %%
# YOUR CODE HERE
animals_original.rename(columns = {"name": "Name", "species":"Species"}, inplace = True)
# raise NotImplementedError()

# %%
animals_original
# Out:
#           Name   Species
# 0        Peter    rabbit
# 1       Nutkin  squirrel
# 2  Hunca Munca     mouse
# 3       Jemima      duck

# %%
assert animals_original.columns[1] == 'Species' # the column number might be different for you

# %% [markdown]
# *Background*: For the curious, the field values you just worked with were inspired by [Beatrix Potter's](https://en.wikipedia.org/wiki/Beatrix_Potter) characters.

# %% [markdown]
# ## Part 2: CalEnviroScreen Data
# Now that we have learned the basics, we'll use Pandas to wrangle a real-world dataset. Specifically, we will be working with the [California Communities Environmental Health Screening Tool (CalEnviroScreen)](https://oehha.ca.gov/calenviroscreen/report/calenviroscreen-30), which uses demographic and environmental information to identify communities that are susceptible to various types of pollution. The various fields in this dataset contribute to the CES score, which reflects a community's environmental conditions and its vulnerability to environmental pollutants.
#
# Your lab02 folder contains an Excel file downloaded from [here](https://oehha.ca.gov/media/downloads/calenviroscreen/document/ces3results.xlsx).
#
# Start by running the cell below, which creates an Excel file object in Pandas that we can then inspect. The cell below shows you the sheet names in the spreadsheet. Documentation on Pandas' Excel methods can be found [here](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_excel.html).

# %%
# run this cell to import the Excel file and see the names of the tabs
filename = 'ces3results.xlsx'
xl = pd.ExcelFile(filename)
print(xl.sheet_names) # display a list of the sheets in the spreadsheet
# Out:
# ['CES 3.0 (2018 Update)', 'Data Dictionary', 'Missing&NAData', 'Demographic profile']

# %% [markdown]
# Run the cell below to load the first sheet of the Excel file and assign it to the variable `ces3`.

# %%
ces3 = xl.parse(xl.sheet_names[0]) # display the first sheet as Pandas dataframe
ces3.head()
# Out:
#    Census Tract  Total Population California County    ZIP  \
# 0    6019001100              3174           Fresno   93706
# 1    6071001600              6133    San Bernardino  91761
# 2    6019000200              3167           Fresno   93706
# 3    6077000801              6692       San Joaquin  95203
# 4    6019001500              2206           Fresno   93725
#
#   Nearby City \n(to help approximate location only)   Longitude   Latitude  \
# 0                                            Fresno -119.781696  36.709695
# 1                                           Ontario -117.618013  34.057780
# 2                                            Fresno -119.805504  36.735491
# 3                                          Stockton -121.314524  37.940517
# 4                                            Fresno -119.717843  36.681600
#
#    CES 3.0 Score   CES 3.0 Percentile CES 3.0 \nPercentile Range  ...  \
# 0      94.090246           100.000000   95-100% (highest scores)  ...
# 1      90.677839            99.987388   95-100% (highest scores)  ...
# 2      85.970036            99.974776   95-100% (highest scores)  ...
# 3      82.491521            99.962164   95-100% (highest scores)  ...
# 4      82.030814            99.949552   95-100% (highest scores)  ...
#
#   Linguistic Isolation Pctl  Poverty  Poverty Pctl  Unemployment  \
# 0                 77.509665     76.3     97.121307          17.6
# 1                 96.253833     72.5     94.632307          12.3
# 2                 78.389548     86.8     99.560025          16.1
# 3                 75.136648     61.3     85.568825          19.6
# 4                 73.723504     66.4     90.232558          18.6
#
#    Unemployment Pctl  Housing Burden  Housing Burden Pctl  Pop. Char.   \
# 0          91.724838            26.0            79.398324    92.120494
# 1          71.823836            34.1            93.754760    87.436849
# 2          87.980708            40.1            97.854785    94.581328
# 3          94.973981            21.1            63.544047    86.701266
# 4          93.654017            28.1            83.980706    80.075199
#
#    Pop. Char. Score  Pop. Char. Pctl
# 0          9.553509        99.697314
# 1          9.067784        98.108210
# 2          9.808714        99.987388
# 3          8.991499        97.717241
# 4          8.304332        92.760752
#
# [5 rows x 57 columns]

# %% [markdown]
# Note that the dataframe contains 57 columns, but Pandas truncates the number we are able to see at once. We can show all columns using the `pd.set_option` method.

# %%
pd.set_option('display.max_columns', None)
ces3.head()
# Out:
#    Census Tract  Total Population California County    ZIP  \
# 0    6019001100              3174           Fresno   93706
# 1    6071001600              6133    San Bernardino  91761
# 2    6019000200              3167           Fresno   93706
# 3    6077000801              6692       San Joaquin  95203
# 4    6019001500              2206           Fresno   93725
#
#   Nearby City \n(to help approximate location only)   Longitude   Latitude  \
# 0                                            Fresno -119.781696  36.709695
# 1                                           Ontario -117.618013  34.057780
# 2                                            Fresno -119.805504  36.735491
# 3                                          Stockton -121.314524  37.940517
# 4                                            Fresno -119.717843  36.681600
#
#    CES 3.0 Score   CES 3.0 Percentile CES 3.0 \nPercentile Range  \
# 0      94.090246           100.000000   95-100% (highest scores)
# 1      90.677839            99.987388   95-100% (highest scores)
# 2      85.970036            99.974776   95-100% (highest scores)
# 3      82.491521            99.962164   95-100% (highest scores)
# 4      82.030814            99.949552   95-100% (highest scores)
#
#   SB 535 Disadvantaged Community     Ozone  Ozone Pctl  PM2.5  PM2.5 Pctl  \
# 0                            Yes  0.064889   98.182950  15.40   97.218064
# 1                            Yes  0.062163   91.101431  13.31   93.637725
# 2                            Yes  0.062163   91.101431  15.40   97.218064
# 3                            Yes  0.046178   53.018046  12.54   84.019461
# 4                            Yes  0.064889   98.182950  15.40   97.218064
#
#    Diesel PM  Diesel PM Pctl  Drinking Water  Drinking Water Pctl  \
# 0  48.523809       95.544493      681.195604            80.915554
# 1  38.556339       92.121966      904.657603            96.108270
# 2  47.445208       95.420037      681.195604            80.915554
# 3  24.117036       73.515868      278.756235            29.113135
# 4  18.845944       58.220286     1000.240794            98.640389
#
#     Pesticides  Pesticides Pctl  Tox. Release  Tox. Release Pctl  Traffic  \
# 0     2.749604        47.818560  18551.957190          97.455725   909.14
# 1     1.365360        41.343490   7494.236622          89.049638   782.26
# 2     3.025629        48.753463  12454.948410          95.422799   576.52
# 3    12.926266        60.560942   2387.782922          69.967573  1305.01
# 4  3518.413336        95.152355  21790.706720          98.154153   435.16
#
#    Traffic Pctl  Cleanup Sites  Cleanup Sites Pctl  Groundwater Threats  \
# 0     62.977817           80.5           98.668369                45.75
# 1     55.658604           66.2           97.683327                36.00
# 2     39.002381           22.0           85.133163                30.25
# 3     78.293019           50.1           96.096315               132.10
# 4     24.301291           60.0           97.154323                54.20
#
#    Groundwater Threats Pctl  Haz. Waste  Haz. Waste Pctl  Imp. Water Bodies  \
# 0                 89.854353       0.795        84.318814                  0
# 1                 85.567693       1.250        88.767377                  5
# 2                 81.926514       0.200        60.500463                  0
# 3                 98.411122       0.795        84.318814                 19
# 4                 92.088712      13.100        99.703429                  0
#
#    Imp. Water Bodies Pctl  Solid Waste  Solid Waste Pctl  Pollution Burden  \
# 0                0.000000        21.75         97.807121         79.958783
# 1               55.007738        12.00         92.171658         81.186627
# 2                0.000000         2.50         57.179910         71.157311
# 3               98.629228        27.00         99.103985         74.483778
# 4                0.000000        50.80         99.905683         80.196761
#
#    Pollution Burden Score  Pollution Burden Pctl  Asthma  Asthma Pctl  \
# 0                9.848763              99.950218  131.64    97.668620
# 1               10.000000             100.000000   60.66    69.779329
# 2                8.764659              99.004356  142.12    98.329385
# 3                9.174390              99.589297  142.17    98.341853
# 4                9.878075              99.987554   90.48    89.539958
#
#    Low Birth Weight  Low Birth Weight Pctl  Cardiovascular Disease  \
# 0              7.44              93.835704                   14.13
# 1              7.04              90.849673                   12.94
# 2             10.16              99.782135                   14.96
# 3              6.23              80.648469                   14.72
# 4              4.50              38.920928                   12.82
#
#    Cardiovascular Disease Pctl  Education  Education Pctl  \
# 0                    96.309687       53.3       95.760787
# 1                    92.656776       53.3       95.760787
# 2                    97.668620       42.3       89.061317
# 3                    97.169929       40.8       87.522079
# 4                    92.357561       45.1       91.130457
#
#    Linguistic Isolation  Linguistic Isolation Pctl  Poverty  Poverty Pctl  \
# 0                  16.2                  77.509665     76.3     97.121307
# 1                  33.4                  96.253833     72.5     94.632307
# 2                  16.7                  78.389548     86.8     99.560025
# 3                  15.3                  75.136648     61.3     85.568825
# 4                  14.7                  73.723504     66.4     90.232558
#
#    Unemployment  Unemployment Pctl  Housing Burden  Housing Burden Pctl  \
# 0          17.6          91.724838            26.0            79.398324
# 1          12.3          71.823836            34.1            93.754760
# 2          16.1          87.980708            40.1            97.854785
# 3          19.6          94.973981            21.1            63.544047
# 4          18.6          93.654017            28.1            83.980706
#
#    Pop. Char.   Pop. Char. Score  Pop. Char. Pctl
# 0    92.120494          9.553509        99.697314
# 1    87.436849          9.067784        98.108210
# 2    94.581328          9.808714        99.987388
# 3    86.701266          8.991499        97.717241
# 4    80.075199          8.304332        92.760752

# %% [markdown]
# Notice that this dataset doesn't include the units in many of the column headings. Let's take a look at a different sheet to get more information about what we're looking at.
#
# Run the following cell to load the data dictionary.

# %%
dd = xl.parse('Data Dictionary', header = 6)
dd.head(10)
# Out:
#                                        Variable Name  \
# 0                                       Census Tract
# 1                                   Total Population
# 2                                  California County
# 3                                                ZIP
# 4  Nearby City \n(to help approximate location only)
# 5                                          Longitude
# 6                                           Latitude
# 7                                      CES 3.0 Score
# 8                                 CES 3.0 Percentile
# 9                           CES 3.0 Percentile Range
#
#                                          Description CalEnviroScreen Category
# 0                   Census Tract ID from 2010 Census                      NaN
# 1                  2010 population in census tracts                       NaN
# 2  California county that the census tract falls ...                      NaN
# 3  Postal ZIP Code that the census tract falls wi...                      NaN
# 4  City or nearby city the  census tract falls wi...                      NaN
# 5      Longitude of the centroid of the census tract                      NaN
# 6       Latitude of the centroid of the census tract                      NaN
# 7  CalEnviroScreen Score, Pollution Score multipl...                      NaN
# 8            Percentile of the CalEnviroScreen score                      NaN
# 9  Percentile of the CalEnviroScreen score, group...                      NaN

# %% [markdown]
# ### Question 4
# The length of a dataframe is equivalent to its number of rows. Find the length of `ces3`. What does each row represent?

# %%
# YOUR CODE HERE
len(ces3)
# Out:
# 8035

# %% [markdown]
# *YOUR ANSWER HERE*
#
# *Each row represents observations for a unique census tract.*

# %% [markdown]
# ## Slicing Data Frames - selecting rows and columns

# %% [markdown]
# ### Selection Using Label
#
# **Column Selection**
# To select a column of a `DataFrame` by column label, the safest and fastest way is to use the `.loc` [method](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html). General usage looks like `frame.loc[rowname,colname]`. (Reminder that the colon `:` means "everything").
#
# - You can also slice across columns. For example, `ces3.loc[:, 'ZIP':]` would select all rows in the column `ZIP` and every column to the right.
#
# - *Alternative:* While `.loc` is invaluable when writing production code, it may be a little too verbose for interactive use. One recommended alternative is the `[]` method, which takes on the form `frame['colname']`.
#
# **Row Selection**
# Similarly, if we want to select a row by its label, we can use the same `.loc` method. In this case, the "label" of each row refers to the index (i.e., primary key) of the dataframe.

# %%
#Example:
ces3.loc[100:110, 'ZIP']
# Out:
# 100    90003
# 101    90810
# 102    92113
# 103    90011
# 104    90501
# 105    91732
# 106    91352
# 107    95358
# 108    90059
# 109    95203
# 110    90058
# Name: ZIP, dtype: int64

# %%
#Example:  Notice the difference between these two methods
ces3.loc[100:110, ['ZIP']]
# Out:
#        ZIP
# 100  90003
# 101  90810
# 102  92113
# 103  90011
# 104  90501
# 105  91732
# 106  91352
# 107  95358
# 108  90059
# 109  95203
# 110  90058

# %% [markdown]
# The `.loc` method actually uses the index (the bolded, leftmost series in the dataframe) rather than the row position to perform the selection. In the previous example, it's just a coincidence that the `.loc` syntax matches that of the array slicing syntax - the index and row position aren't always the same value. For example, you could set your index to a non-numeric code, like census tract or other unique ID, if that's how you want to identify your records.
#
# Alternatively, we can use [`.iloc`](http://pandas.pydata.org/pandas-docs/version/0.17.0/generated/pandas.DataFrame.iloc.html) to slice the dataframe using row location and column position.
#
# See the following example:

# %%
#Example: We change the index from 0,1,2... to the Census Tract column
df = ces3.set_index("Census Tract") # Why might we want to use Census Tract instead of County or City?
df.head()
# Out:
#               Total Population California County    ZIP  \
# Census Tract
# 6019001100                3174           Fresno   93706
# 6071001600                6133    San Bernardino  91761
# 6019000200                3167           Fresno   93706
# 6077000801                6692       San Joaquin  95203
# 6019001500                2206           Fresno   93725
#
#              Nearby City \n(to help approximate location only)   Longitude  \
# Census Tract
# 6019001100                                              Fresno -119.781696
# 6071001600                                             Ontario -117.618013
# 6019000200                                              Fresno -119.805504
# 6077000801                                            Stockton -121.314524
# 6019001500                                              Fresno -119.717843
#
#                Latitude  CES 3.0 Score   CES 3.0 Percentile  \
# Census Tract
# 6019001100    36.709695      94.090246           100.000000
# 6071001600    34.057780      90.677839            99.987388
# 6019000200    36.735491      85.970036            99.974776
# 6077000801    37.940517      82.491521            99.962164
# 6019001500    36.681600      82.030814            99.949552
#
#              CES 3.0 \nPercentile Range SB 535 Disadvantaged Community  \
# Census Tract
# 6019001100     95-100% (highest scores)                            Yes
# 6071001600     95-100% (highest scores)                            Yes
# 6019000200     95-100% (highest scores)                            Yes
# 6077000801     95-100% (highest scores)                            Yes
# 6019001500     95-100% (highest scores)                            Yes
#
#                  Ozone  Ozone Pctl  PM2.5  PM2.5 Pctl  Diesel PM  \
# Census Tract
# 6019001100    0.064889   98.182950  15.40   97.218064  48.523809
# 6071001600    0.062163   91.101431  13.31   93.637725  38.556339
# 6019000200    0.062163   91.101431  15.40   97.218064  47.445208
# 6077000801    0.046178   53.018046  12.54   84.019461  24.117036
# 6019001500    0.064889   98.182950  15.40   97.218064  18.845944
#
#               Diesel PM Pctl  Drinking Water  Drinking Water Pctl  \
# Census Tract
# 6019001100         95.544493      681.195604            80.915554
# 6071001600         92.121966      904.657603            96.108270
# 6019000200         95.420037      681.195604            80.915554
# 6077000801         73.515868      278.756235            29.113135
# 6019001500         58.220286     1000.240794            98.640389
#
#                Pesticides  Pesticides Pctl  Tox. Release  Tox. Release Pctl  \
# Census Tract
# 6019001100       2.749604        47.818560  18551.957190          97.455725
# 6071001600       1.365360        41.343490   7494.236622          89.049638
# 6019000200       3.025629        48.753463  12454.948410          95.422799
# 6077000801      12.926266        60.560942   2387.782922          69.967573
# 6019001500    3518.413336        95.152355  21790.706720          98.154153
#
#               Traffic  Traffic Pctl  Cleanup Sites  Cleanup Sites Pctl  \
# Census Tract
# 6019001100     909.14     62.977817           80.5           98.668369
# 6071001600     782.26     55.658604           66.2           97.683327
# 6019000200     576.52     39.002381           22.0           85.133163
# 6077000801    1305.01     78.293019           50.1           96.096315
# 6019001500     435.16     24.301291           60.0           97.154323
#
#               Groundwater Threats  Groundwater Threats Pctl  Haz. Waste  \
# Census Tract
# 6019001100                  45.75                 89.854353       0.795
# 6071001600                  36.00                 85.567693       1.250
# 6019000200                  30.25                 81.926514       0.200
# 6077000801                 132.10                 98.411122       0.795
# 6019001500                  54.20                 92.088712      13.100
#
#               Haz. Waste Pctl  Imp. Water Bodies  Imp. Water Bodies Pctl  \
# Census Tract
# 6019001100          84.318814                  0                0.000000
# 6071001600          88.767377                  5               55.007738
# 6019000200          60.500463                  0                0.000000
# 6077000801          84.318814                 19               98.629228
# 6019001500          99.703429                  0                0.000000
#
#               Solid Waste  Solid Waste Pctl  Pollution Burden  \
# Census Tract
# 6019001100          21.75         97.807121         79.958783
# 6071001600          12.00         92.171658         81.186627
# 6019000200           2.50         57.179910         71.157311
# 6077000801          27.00         99.103985         74.483778
# 6019001500          50.80         99.905683         80.196761
#
#               Pollution Burden Score  Pollution Burden Pctl  Asthma  \
# Census Tract
# 6019001100                  9.848763              99.950218  131.64
# 6071001600                 10.000000             100.000000   60.66
# 6019000200                  8.764659              99.004356  142.12
# 6077000801                  9.174390              99.589297  142.17
# 6019001500                  9.878075              99.987554   90.48
#
#               Asthma Pctl  Low Birth Weight  Low Birth Weight Pctl  \
# Census Tract
# 6019001100      97.668620              7.44              93.835704
# 6071001600      69.779329              7.04              90.849673
# 6019000200      98.329385             10.16              99.782135
# 6077000801      98.341853              6.23              80.648469
# 6019001500      89.539958              4.50              38.920928
#
#               Cardiovascular Disease  Cardiovascular Disease Pctl  Education  \
# Census Tract
# 6019001100                     14.13                    96.309687       53.3
# 6071001600                     12.94                    92.656776       53.3
# 6019000200                     14.96                    97.668620       42.3
# 6077000801                     14.72                    97.169929       40.8
# 6019001500                     12.82                    92.357561       45.1
#
#               Education Pctl  Linguistic Isolation  Linguistic Isolation Pctl  \
# Census Tract
# 6019001100         95.760787                  16.2                  77.509665
# 6071001600         95.760787                  33.4                  96.253833
# 6019000200         89.061317                  16.7                  78.389548
# 6077000801         87.522079                  15.3                  75.136648
# 6019001500         91.130457                  14.7                  73.723504
#
#               Poverty  Poverty Pctl  Unemployment  Unemployment Pctl  \
# Census Tract
# 6019001100       76.3     97.121307          17.6          91.724838
# 6071001600       72.5     94.632307          12.3          71.823836
# 6019000200       86.8     99.560025          16.1          87.980708
# 6077000801       61.3     85.568825          19.6          94.973981
# 6019001500       66.4     90.232558          18.6          93.654017
#
#               Housing Burden  Housing Burden Pctl  Pop. Char.   \
# Census Tract
# 6019001100              26.0            79.398324    92.120494
# 6071001600              34.1            93.754760    87.436849
# 6019000200              40.1            97.854785    94.581328
# 6077000801              21.1            63.544047    86.701266
# 6019001500              28.1            83.980706    80.075199
#
#               Pop. Char. Score  Pop. Char. Pctl
# Census Tract
# 6019001100            9.553509        99.697314
# 6071001600            9.067784        98.108210
# 6019000200            9.808714        99.987388
# 6077000801            8.991499        97.717241
# 6019001500            8.304332        92.760752

# %% [markdown]
# We can now lookup rows by name directly:

# %%
df.loc[[6037205120, 6019000200], :]
# Out:
#               Total Population California County    ZIP  \
# Census Tract
# 6037205120                3618       Los Angeles  90023
# 6019000200                3167           Fresno   93706
#
#              Nearby City \n(to help approximate location only)   Longitude  \
# Census Tract
# 6037205120                                         Los Angeles -118.211796
# 6019000200                                              Fresno -119.805504
#
#                Latitude  CES 3.0 Score   CES 3.0 Percentile  \
# Census Tract
# 6037205120    34.018755      78.043685            99.823433
# 6019000200    36.735491      85.970036            99.974776
#
#              CES 3.0 \nPercentile Range SB 535 Disadvantaged Community  \
# Census Tract
# 6037205120     95-100% (highest scores)                            Yes
# 6019000200     95-100% (highest scores)                            Yes
#
#                  Ozone  Ozone Pctl  PM2.5  PM2.5 Pctl  Diesel PM  \
# Census Tract
# 6037205120    0.046178   53.018046  12.89   92.889222  50.075299
# 6019000200    0.062163   91.101431  15.40   97.218064  47.445208
#
#               Diesel PM Pctl  Drinking Water  Drinking Water Pctl  Pesticides  \
# Census Tract
# 6037205120         95.967642      664.069078            78.570538    0.000000
# 6019000200         95.420037      681.195604            80.915554    3.025629
#
#               Pesticides Pctl  Tox. Release  Tox. Release Pctl  Traffic  \
# Census Tract
# 6037205120           0.000000   19178.66447          97.567972   887.21
# 6019000200          48.753463   12454.94841          95.422799   576.52
#
#               Traffic Pctl  Cleanup Sites  Cleanup Sites Pctl  \
# Census Tract
# 6037205120       62.000251          49.45           96.041591
# 6019000200       39.002381          22.00           85.133163
#
#               Groundwater Threats  Groundwater Threats Pctl  Haz. Waste  \
# Census Tract
# 6037205120                  37.25                 86.180073       17.72
# 6019000200                  30.25                 81.926514        0.20
#
#               Haz. Waste Pctl  Imp. Water Bodies  Imp. Water Bodies Pctl  \
# Census Tract
# 6037205120          99.888786                  7               71.611762
# 6019000200          60.500463                  0                0.000000
#
#               Solid Waste  Solid Waste Pctl  Pollution Burden  \
# Census Tract
# 6037205120          14.75         94.765386         75.614761
# 6019000200           2.50         57.179910         71.157311
#
#               Pollution Burden Score  Pollution Burden Pctl  Asthma  \
# Census Tract
# 6037205120                  9.313697              99.751089   68.74
# 6019000200                  8.764659              99.004356  142.12
#
#               Asthma Pctl  Low Birth Weight  Low Birth Weight Pctl  \
# Census Tract
# 6037205120      77.633712              5.14              56.273228
# 6019000200      98.329385             10.16              99.782135
#
#               Cardiovascular Disease  Cardiovascular Disease Pctl  Education  \
# Census Tract
# 6037205120                     10.40                    77.621244       61.4
# 6019000200                     14.96                    97.668620       42.3
#
#               Education Pctl  Linguistic Isolation  Linguistic Isolation Pctl  \
# Census Tract
# 6037205120         98.675246                  28.4                  93.307559
# 6019000200         89.061317                  16.7                  78.389548
#
#               Poverty  Poverty Pctl  Unemployment  Unemployment Pctl  \
# Census Tract
# 6037205120       78.3     97.737272          16.9          90.201802
# 6019000200       86.8     99.560025          16.1          87.980708
#
#               Housing Burden  Housing Burden Pctl  Pop. Char.   \
# Census Tract
# 6037205120              24.6            75.526783    80.799564
# 6019000200              40.1            97.854785    94.581328
#
#               Pop. Char. Score  Pop. Char. Pctl
# Census Tract
# 6037205120            8.379453        93.441796
# 6019000200            9.808714        99.987388

# %% [markdown]
# However, if we want to access rows by location we will need to use the integer loc (`iloc`) accessor:

# %%
#Example: 
# df.loc[2:5,"Year"] # You can't do this
df.iloc[1:4,6:9]
# Out:
#               CES 3.0 Score   CES 3.0 Percentile CES 3.0 \nPercentile Range
# Census Tract
# 6071001600        90.677839            99.987388   95-100% (highest scores)
# 6019000200        85.970036            99.974776   95-100% (highest scores)
# 6077000801        82.491521            99.962164   95-100% (highest scores)

# %% [markdown]
# ### Question 4
#
# Selecting multiple columns is easy using `.loc`.  You just need to supply a list of column names.  Select the `California County`,`Diesel PM Pctl`, and `PM2.5 Pctl` columns **in that order** from the `ces3` table.

# %%
# YOUR CODE HERE
dsl_O3_PM = ces3.loc[:, ["California County", "Diesel PM Pctl","PM2.5 Pctl"]]
#raise NotImplementedError()

# %%
dsl_O3_PM.head()
# Out:
#   California County  Diesel PM Pctl  PM2.5 Pctl
# 0           Fresno        95.544493   97.218064
# 1    San Bernardino       92.121966   93.637725
# 2           Fresno        95.420037   97.218064
# 3       San Joaquin       73.515868   84.019461
# 4           Fresno        58.220286   97.218064

# %%
assert dsl_O3_PM.shape == (8035, 3)
assert dsl_O3_PM.columns[1] == "Diesel PM Pctl"

# %% [markdown]
# As you may have noticed above, the .loc() method is a way to re-order the columns within a dataframe.

# %% [markdown]
# ## Filtering Data

# %% [markdown]
# ### Filtering with boolean arrays
#
# Filtering is the process of removing unwanted material.  In your quest for cleaner data, you will undoubtedly filter your data at some point: whether it be for clearing up cases with missing values, culling out fishy outliers, or analyzing subgroups of your data set.  Note that compound expressions have to be grouped with brackets. Example usage looks like `df[df[column name] < 5]]`.
#
# For your reference, some commonly used comparison operators are given below.
#
# Symbol | Usage      | Meaning
# ------ | ---------- | -------------------------------------
# ==   | a == b   | Does a equal b?
# <=   | a <= b   | Is a less than or equal to b?
# >=   | a >= b   | Is a greater than or equal to b?
# <    | a < b    | Is a less than b?
# &#62;    | a &#62; b    | Is a greater than b?
# ~    | ~p       | Returns negation of p
# &#124; | p &#124; q | p OR q
# &    | p & q    | p AND q
# ^  | p ^ q | p XOR q (exclusive or)

# %% [markdown]
# In the following we construct the DataFrame containing only census tracts in Sacramento County.

# %%
ces3_SC = ces3[ces3['California County'] == 'Sacramento '] # Note the space after "Sacramento." This kind of quirk can be remedied with some simple data cleaning techniques, which we'll discuss in future lessons.
ces3_SC.head(5)
# Out:
#      Census Tract  Total Population California County    ZIP  \
# 75     6067005301              1823       Sacramento   95811
# 213    6067000700              2806       Sacramento   95814
# 409    6067005205              2109       Sacramento   95826
# 443    6067002200              4004       Sacramento   95818
# 538    6067004502              4795       Sacramento   95823
#
#     Nearby City \n(to help approximate location only)   Longitude   Latitude  \
# 75                                         Sacramento -121.482520  38.591604
# 213                                        Sacramento -121.501660  38.581871
# 409                                        Sacramento -121.395510  38.537469
# 443                                        Sacramento -121.507156  38.561282
# 538                                        Sacramento -121.462926  38.502552
#
#      CES 3.0 Score   CES 3.0 Percentile CES 3.0 \nPercentile Range  \
# 75       68.638370            99.054105   95-100% (highest scores)
# 213      62.369337            97.313659   95-100% (highest scores)
# 409      57.392670            94.841720                     90-95%
# 443      56.601381            94.412915                     90-95%
# 538      54.936674            93.214781                     90-95%
#
#     SB 535 Disadvantaged Community     Ozone  Ozone Pctl     PM2.5  \
# 75                             Yes  0.046178   53.018046  9.536303
# 213                            Yes  0.046178   53.018046  9.536303
# 409                            Yes  0.049512   64.803983  9.536303
# 443                            Yes  0.046178   53.018046  9.536303
# 538                            Yes  0.047908   60.883634  9.536303
#
#      PM2.5 Pctl  Diesel PM  Diesel PM Pctl  Drinking Water  \
# 75    40.918164  17.793975       53.976353       80.014449
# 213   40.918164  23.724534       72.682016       80.014449
# 409   40.918164  14.080196       42.887368      196.400036
# 443   40.918164  28.030000       81.804605       80.014449
# 538   40.918164  13.984471       42.538892     1004.338953
#
#      Drinking Water Pctl  Pesticides  Pesticides Pctl  Tox. Release  \
# 75              6.261694    0.413440        31.371191   1700.626695
# 213             6.261694    0.000000         0.000000    780.622745
# 409            14.756143    0.089021        20.083102    438.072221
# 443             6.261694    0.634822        34.729917    333.863166
# 538            98.690283    0.000000         0.000000    195.712488
#
#      Tox. Release Pctl  Traffic  Traffic Pctl  Cleanup Sites  \
# 75           66.038912  1391.76     80.561474         163.65
# 213          57.420803  1066.23     70.459957         115.60
# 409          48.740334  1443.80     81.689435          23.50
# 443          43.776503  1490.40     82.742198          22.90
# 538          35.420304  1594.61     84.785061           5.50
#
#      Cleanup Sites Pctl  Groundwater Threats  Groundwater Threats Pctl  \
# 75            99.872309               121.25                 97.964250
# 213           99.525721                65.85                 94.223767
# 409           86.191171                58.75                 93.048659
# 443           85.698650                55.50                 92.386627
# 538           45.986866                18.00                 67.643165
#
#      Haz. Waste  Haz. Waste Pctl  Imp. Water Bodies  Imp. Water Bodies Pctl  \
# 75        0.450        74.235403                 17               97.722750
# 213       0.675        82.298424                 16               97.258457
# 409       2.110        92.177943                  7               71.611762
# 443       2.660        93.790547                 16               97.258457
# 538       0.200        60.500463                  4               48.795048
#
#      Solid Waste  Solid Waste Pctl  Pollution Burden  Pollution Burden Score  \
# 75          15.0         95.024758         62.620901                7.713204
# 213          0.0          0.000000         53.530966                6.593569
# 409         67.5         99.952841         59.425352                7.319599
# 443          5.0         73.543975         62.202467                7.661664
# 538          0.0          0.000000         49.455640                6.091599
#
#      Pollution Burden Pctl  Asthma  Asthma Pctl  Low Birth Weight  \
# 75               94.424393   76.08    82.695425             14.89
# 213              80.771624  110.76    94.838549               NaN
# 409              90.728065   64.34    73.681586              6.80
# 443              94.001245   71.28    79.503803              5.83
# 538              71.101431  132.87    97.743424              6.13
#
#      Low Birth Weight Pctl  Cardiovascular Disease  \
# 75              100.000000                    9.25
# 213                    NaN                   13.30
# 409              88.619762                   10.13
# 443              73.087274                   10.29
# 538              78.777393                   15.57
#
#      Cardiovascular Disease Pctl  Education  Education Pctl  \
# 75                     66.089016       22.8       66.868534
# 213                    93.990774       38.8       85.856674
# 409                    75.813490       11.6       43.969215
# 443                    76.948011       17.7       57.607873
# 538                    98.304451       22.7       66.717133
#
#      Linguistic Isolation  Linguistic Isolation Pctl  Poverty  Poverty Pctl  \
# 75                    NaN                        NaN     90.8     99.836581
# 213                  36.5                  97.320357     82.1     98.893777
# 409                   7.2                  47.340355     63.8     87.944689
# 443                  10.4                  60.471937     59.4     83.746072
# 538                  11.7                  65.017998     72.4     94.569453
#
#      Unemployment  Unemployment Pctl  Housing Burden  Housing Burden Pctl  \
# 75           60.5          99.987308            30.2            88.055344
# 213          38.3          99.949232            19.8            58.009647
# 409          15.6          86.609976            33.7            93.348566
# 443          16.8          89.909887            15.6            38.055344
# 538          23.4          98.197741            29.6            87.065245
#
#      Pop. Char.   Pop. Char. Score  Pop. Char. Pctl
# 75     85.807544          8.898814        97.313659
# 213    91.210300          9.459116        99.520747
# 409    75.607086          7.840959        87.854711
# 443    71.235626          7.387609        81.422626
# 538    86.960968          9.018432        97.881196

# %% [markdown]
# ### Question 5
# Select the census tracts in Alameda county whose CES 3.0 Percentile is 90 or higher.
#
# (If you use condition `p` & condition `q` to filter the dataframe, make sure to use `df[(p) & (q)]`)
#
# Hint: The column names, like the county names, are not "clean." Try using the `.columns` method to look up the **exact** column names.

# %%
# YOUR CODE HERE
AC_highCES = ces3[(ces3["California County"] == "Alameda ") & (ces3[' CES 3.0 Percentile']>=90)]
#raise NotImplementedError()

# %%
AC_highCES
# Out:
#      Census Tract  Total Population California County    ZIP  \
# 245    6001409000              3552          Alameda   94621
# 287    6001409100              2255          Alameda   94603
# 300    6001408800              5547          Alameda   94621
# 517    6001409200              3152          Alameda   94603
# 701    6001407300              2598          Alameda   94601
# 769    6001409500              3122          Alameda   94621
#
#     Nearby City \n(to help approximate location only)   Longitude   Latitude  \
# 245                                           Oakland -122.221368  37.720011
# 287                                           Oakland -122.183500  37.732326
# 300                                           Oakland -122.196942  37.758804
# 517                                           Oakland -122.177787  37.729085
# 701                                           Oakland -122.210924  37.762179
# 769                                           Oakland -122.183766  37.750446
#
#      CES 3.0 Score   CES 3.0 Percentile CES 3.0 \nPercentile Range  \
# 245      61.560437            96.910077   95-100% (highest scores)
# 287      59.868084            96.380376   95-100% (highest scores)
# 300      59.647241            96.216421   95-100% (highest scores)
# 517      55.292008            93.479632                     90-95%
# 701      52.539247            91.159036                     90-95%
# 769      51.441952            90.301425                     90-95%
#
#     SB 535 Disadvantaged Community     Ozone  Ozone Pctl     PM2.5  \
# 245                            Yes  0.029592     7.57934  8.697944
# 287                            Yes  0.029592     7.57934  8.697944
# 300                            Yes  0.029592     7.57934  8.697944
# 517                            Yes  0.029592     7.57934  8.697944
# 701                            Yes  0.029592     7.57934  8.697944
# 769                            Yes  0.029592     7.57934  8.697944
#
#      PM2.5 Pctl  Diesel PM  Diesel PM Pctl  Drinking Water  \
# 245   30.701098  38.280000       91.897946       70.599583
# 287   30.701098  37.550043       91.524580       70.599583
# 300   30.701098  38.315076       91.922838       70.599583
# 517   30.701098  31.079042       86.708152       70.599583
# 701   30.701098  38.354234       91.935283       70.599583
# 769   30.701098  35.084981       89.732421       70.599583
#
#      Drinking Water Pctl  Pesticides  Pesticides Pctl  Tox. Release  \
# 245             4.465511         0.0              0.0    596.167763
# 287             4.465511         0.0              0.0    611.929394
# 300             4.465511         0.0              0.0    548.091921
# 517             4.465511         0.0              0.0    665.694179
# 701             4.465511         0.0              0.0    364.462799
# 769             4.465511         0.0              0.0    532.088175
#
#      Tox. Release Pctl  Traffic  Traffic Pctl  Cleanup Sites  \
# 245          53.579446  1419.88     81.200652          63.15
# 287          53.853829  2145.76     92.267201          45.70
# 300          52.282365   411.44     22.245895          46.05
# 517          55.101023  4291.67     99.724276          57.60
# 701          45.422799  1406.60     80.837198          79.45
# 769          51.758543   346.51     16.067176          25.85
#
#      Cleanup Sites Pctl  Groundwater Threats  Groundwater Threats Pctl  \
# 245           97.446188               118.50                 97.881496
# 287           95.384896                25.10                 77.375041
# 300           95.457862                37.65                 86.511089
# 517           96.825976                28.00                 80.023171
# 701           98.595403               183.05                 99.189010
# 769           88.106530                40.85                 88.099967
#
#      Haz. Waste  Haz. Waste Pctl  Imp. Water Bodies  Imp. Water Bodies Pctl  \
# 245       2.700        93.938832                 15               95.644484
# 287       0.335        70.769231                 11               89.542339
# 300       0.810        84.559778                 15               95.644484
# 517       0.545        78.313253                 11               89.542339
# 701       0.860        85.152919                 16               97.258457
# 769       3.560        95.162187                  1               15.255361
#
#      Solid Waste  Solid Waste Pctl  Pollution Burden  Pollution Burden Score  \
# 245        11.45         91.393539         57.413064                7.071739
# 287         6.00         78.519217         54.143340                6.668997
# 300        14.00         94.388116         50.360950                6.203109
# 517         5.00         73.543975         54.957476                6.769277
# 701        30.50         99.481254         56.830015                6.999923
# 769        12.50         92.737562         44.367354                5.464860
#
#      Pollution Burden Pctl  Asthma  Asthma Pctl  Low Birth Weight  \
# 245              87.566895  147.84    98.541329              6.15
# 287              82.065961  189.95    99.713253              8.03
# 300              73.640324  161.73    99.064954              8.75
# 517              83.621655  106.59    93.903503              8.38
# 701              86.621033   99.49    92.694178              5.92
# 769              57.013068  161.73    99.064954              7.93
#
#      Low Birth Weight Pctl  Cardiovascular Disease  \
# 245              79.110598                   11.34
# 287              96.642317                   14.44
# 300              98.654364                   11.56
# 517              97.911060                    8.79
# 701              74.791747                    7.73
# 769              96.321927                   11.56
#
#      Cardiovascular Disease Pctl  Education  Education Pctl  \
# 245                    85.114076       28.3       74.577340
# 287                    96.883182       40.0       86.790310
# 300                    86.273532       46.8       92.228110
# 517                    60.728089       30.5       77.037598
# 701                    47.201097       38.1       85.187989
# 769                    86.273532       42.9       89.465052
#
#      Linguistic Isolation  Linguistic Isolation Pctl  Poverty  Poverty Pctl  \
# 245                  18.3                  81.429143     52.5     76.216216
# 287                   7.7                  49.700040     55.8     79.924576
# 300                  18.1                  81.029196     66.5     90.333124
# 517                  11.1                  62.898280     44.4     66.222502
# 701                  19.0                  82.602320     56.3     80.502828
# 769                  21.2                  86.148514     64.2     88.409805
#
#      Unemployment  Unemployment Pctl  Housing Burden  Housing Burden Pctl  \
# 245          13.3          77.395609            32.5            91.838030
# 287          12.6          73.588019            29.5            86.887535
# 300          20.1          95.583196            35.2            94.706778
# 517          13.4          77.877903            27.4            82.673267
# 701           9.6          52.823962            21.4            64.813404
# 769          17.3          91.102932            27.6            83.117543
#
#      Pop. Char.   Pop. Char. Score  Pop. Char. Pctl
# 245    83.939968          8.705134        96.279480
# 287    86.562173          8.977074        97.666793
# 300    92.720182          9.615701        99.785597
# 517    78.761397          8.168082        91.386051
# 701    72.374221          7.505689        83.213520
# 769    90.767787          9.413224        99.419851

# %%
assert len(AC_highCES) == 6
assert AC_highCES[" CES 3.0 Percentile"].max() == 96.9100769327784

# %% [markdown]
# ## Data Aggregration (Grouping Data Frames)
#
# ### Question 6
# To count the number of instances of a value in a `Series`, we can use the `value_counts()` [method](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.Series.value_counts.html) as `df["col_name"].value_counts()`.
#
# Count the number of different census tracts in each Californial county. (You may use the `ces3` DataFrame created above.) In other words, compute the number of rows in the table for each county.

# %%
# YOUR CODE HERE
num_censusTracts = ces3["California County"].value_counts()

#raise NotImplementedError()

# %%
num_censusTracts
# Out:
# Los Angeles        2343
# San Diego           627
# Orange              582
# Riverside           453
# Santa Clara         372
# San Bernardino      369
# Alameda             360
# Sacramento          317
# Contra Costa        207
# Fresno              199
# San Francisco       195
# Ventura             173
# San Mateo           157
# Kern                151
# San Joaquin         139
# Sonoma               99
# Solano               96
# Stanislaus           94
# Monterey             93
# Santa Barbara        89
# Placer               84
# Tulare               78
# Marin                55
# San Luis Obispo      53
# Santa Cruz           52
# Butte                51
# Merced               49
# Shasta               48
# El Dorado            42
# Yolo                 41
# Napa                 40
# Imperial             31
# Humboldt             30
# Kings                27
# Madera               23
# Sutter               21
# Nevada               20
# Mendocino            20
# Lake                 15
# Yuba                 14
# Siskiyou             14
# Tehama               11
# San Benito           11
# Tuolumne             11
# Calaveras            10
# Amador                9
# Lassen                9
# Del Norte             7
# Plumas                7
# Mariposa              6
# Glenn                 6
# Inyo                  6
# Trinity               5
# Colusa                5
# Modoc                 4
# Mono                  3
# Alpine                1
# Sierra                1
# Name: California County, dtype: int64

# %%
assert num_censusTracts["Alameda "] == 360
assert num_censusTracts.sum() == len(ces3)

# %% [markdown]
# ### Question 7a
#
# A more versatile way to aggregate data is to use the `.groupby()` [function](https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.groupby.html). Find the sum of `Imp. Water Bodies` for each `California County` in the `ces3` table. Use the syntax `df.groupby("col_name").sum()`.

# %%
# YOUR CODE HERE
sum_impH2O = ces3.groupby("California County").sum()

# raise NotImplementedError()

# %%
sum_impH2O.sort_values(by = "Imp. Water Bodies", ascending=False)['Imp. Water Bodies']
# Out:
# California County
# Los Angeles        6976
# San Diego          2458
# Orange             1489
# Alameda            1438
# Ventura            1260
# Sacramento         1170
# San Joaquin        1056
# San Francisco      1049
# Contra Costa        983
# Monterey            775
# Santa Clara         744
# Riverside           652
# San Mateo           597
# Imperial            497
# Santa Barbara       478
# Sonoma              450
# Stanislaus          422
# Santa Cruz          362
# Marin               343
# Solano              334
# San Bernardino      276
# San Luis Obispo     245
# Merced              222
# Yolo                204
# Butte               174
# Sutter              159
# Placer              153
# Napa                116
# El Dorado           103
# Humboldt            103
# Shasta               96
# Fresno               94
# San Benito           86
# Siskiyou             70
# Colusa               68
# Tulare               67
# Mendocino            66
# Tehama               49
# Nevada               49
# Yuba                 49
# Lake                 47
# Lassen               47
# Madera               42
# Glenn                40
# Calaveras            24
# Mono                 22
# Tuolumne             20
# Modoc                19
# Kings                18
# Plumas               16
# Trinity              14
# Alpine               13
# Mariposa             13
# Amador                8
# Inyo                  8
# Kern                  6
# Del Norte             5
# Sierra                3
# Name: Imp. Water Bodies, dtype: int64

# %%
assert sum_impH2O.loc["Los Angeles", "Imp. Water Bodies"] == 6976
assert sum_impH2O.sort_values(by = "Imp. Water Bodies", ascending=False).index[3] == "Alameda "

# %% [markdown]
# ### Question 7b
# Take a look at the the Data Dictionary. What does the sum of the `Imp. Water Bodies` column represent?  In the process you'll read about "buffers".  What is a buffer?

# %%
# SCRATCH WORK HERE

# %% [markdown]
# *YOUR ANSWER HERE*
#
# *The sum of the number of pollutants across all impaired water bodies within buffered distances to populated blocks in the **county**.*
#
# *Buffers are areas around an object in space (often a point).  They are often used to aggregate data (as in `groupby`: by averaging, taking the max, counts, etc.) in the vicinity of the object.*

# %% [markdown]
# ### Question 7c
#
# What do the values in `ZIP` represent in the dataframe `sum_impH2O`? Why is the column `CES 3.0 Percentile Range` no longer present in the dataframe?

# %% [markdown]
# *YOUR ANSWER HERE*
#
# *`ZIP` is the sum of all zip codes associated with the census tracts in a given county. Although this isn't particularly meaningful to us, it's how Python interprets the `.sum()` method of `groupby()` - it takes the sum of all numeric values in the dataframe, grouped by the specified column (`California County`).*
#
# *`CES 3.0 Percentile Range` is no longer present in the dataframe because the column does not contain numeric values. Python isn't able to sum the column's values, so it drops it. We could keep this column by grouping by both `California County` and `CES 3.0 Percentile Range` in the groupby - that way, we would get a dataframe that has the total number of pollutants in impaired water bodies by both county and CES 3.0 category.*

# %% [markdown]
# ### Question 7d
#
# Find the mean of `Poverty` for each county for census tracts with population greater than or equal to 3,000 and with a `Pollution Burden Pctl` above 85.

# %%
# YOUR CODE HERE
poverty_mean = ces3[(ces3["Total Population"] >= 3000) & (ces3["Pollution Burden Pctl"] > 85)].groupby("California County").mean()

# raise NotImplementedError()

# %%
poverty_mean.sort_values(by = "Poverty", ascending=False)['Poverty']
# Out:
# California County
# Kings             73.200000
# Butte             72.500000
# Yolo              64.750000
# Fresno            61.354348
# Kern              57.033333
# Merced            49.787500
# San Diego         49.353333
# Tulare            49.080000
# Stanislaus        48.320930
# Los Angeles       47.291725
# Santa Cruz        46.500000
# Riverside         44.760000
# San Joaquin       44.663158
# Madera            44.650000
# Sacramento        44.450000
# San Bernardino    43.964384
# Imperial          40.100000
# Ventura           37.160000
# Santa Clara       36.650000
# Orange            36.213235
# Alameda           31.150000
# San Mateo         21.966667
# San Francisco     20.200000
# Name: Poverty, dtype: float64

# %%
assert np.round(poverty_mean.loc["Alameda ", "Poverty"],2) == 31.15
assert len(poverty_mean) == 23

# %% [markdown]
# ### Question 7e
#
# What does your output to 7d represent?  Dig in to the data a little further and tell us what you notice about the `Poverty` field values in the counties/tract combinations that show up in your result to 7d, versus the `Poverty` field values for all tracts?

# %% [markdown]
# *YOUR ANSWER HERE*
#
# *From the CES documentation, poverty is the "Percent of the population living below two times the federal poverty
# level (5-year estimate, 2011-2015)."  If one digs in to the data, you can find that the poverty percentile for those tracts with high CES scores is higher than the average percentile across all tracts.*

# %% [markdown]
# #### You are done! Remember to submit this lab on bCourses in both html and ipynb formats after clicking Kernel -> Restart & Run All.
